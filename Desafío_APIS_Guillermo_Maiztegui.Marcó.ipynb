# %%
from google.colab import output, drive, files 
import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings

# %% [markdown]
# #EL OBJETIVO AL CONSUMIR DATOS DESDE LA API DE YAHOO FINANCE, ES CONOCER ALGUNOS DATOS FINANCIEROS DEL ECOMERCE DEL QUE TRATA EL PROYECTO FINAL, DURANTE EL MISMO PERIODO QUE ES ANALIZADO EN EL DATAFRAME DE DICHO PROYECTO. ESTE ABARCA DESDE 2020 HASTA 2022

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf
AMAZON = yf.Ticker('AMZN')
AMAZON.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1998-06-02 00:00:00-04:00        0.0           2.0
# 1999-01-05 00:00:00-05:00        0.0           3.0
# 1999-09-02 00:00:00-04:00        0.0           2.0
# 2022-06-06 00:00:00-04:00        0.0          20.0

# %%
AMAZON.history
# Out:
# <bound method TickerBase.history of yfinance.Ticker object <AMZN>>

# %%
hist = AMAZON.history(start="2020-01-01", end="2022-12-31", interval = '1mo')
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-01 00:00:00-05:00   93.750000  102.786003   90.766998  100.435997
# 2020-02-01 00:00:00-05:00  100.529999  109.297501   90.556503   94.187500
# 2020-03-01 00:00:00-05:00   95.324501   99.816498   81.301498   97.486000
# 2020-04-01 00:00:00-04:00   96.648499  123.750000   94.457497  123.699997
# 2020-05-01 00:00:00-04:00  116.839996  126.272499  112.819000  122.118500
# 2020-06-01 00:00:00-04:00  122.400002  139.800003  121.856499  137.940994
# 2020-07-01 00:00:00-04:00  137.899506  167.214493  137.699997  158.233994
# 2020-08-01 00:00:00-04:00  159.025497  174.750000  153.649994  172.548004
# 2020-09-01 00:00:00-04:00  174.479004  177.612503  143.550003  157.436493
# 2020-10-01 00:00:00-04:00  160.399994  174.811996  150.949997  151.807495
# 2020-11-01 00:00:00-04:00  153.087006  168.339996  147.505997  158.401993
# 2020-12-01 00:00:00-05:00  159.425003  167.532501  153.641006  162.846497
# ...

# %%
AMAZON.calendar

# %%
cal = AMAZON.earnings_dates
cal
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-01-31 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-25 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-26 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-26 06:00:00-04:00          0.23           NaN          NaN
# 2023-02-02 11:00:00-05:00          0.18          0.03      -0.8286
# 2022-10-27 12:00:00-04:00          0.22          0.28       0.3023
# 2022-07-28 12:00:00-04:00          0.14         -0.20      -2.3889
# 2022-04-28 12:00:00-04:00          0.42         -0.38      -1.9043
# 2022-02-03 11:00:00-05:00          0.18          1.39       6.7978
# 2021-10-28 12:00:00-04:00          0.45          0.31      -0.3139
# 2021-07-29 12:00:00-04:00          0.62          0.76       0.2293
# 2021-04-29 12:00:00-04:00          0.48          0.79       0.6562

# %%
AMAZON.get_shares_full(start="2020-01-01", end="2022-12-31")
# Out:
# 2020-01-07 00:00:00-05:00      501889984
# 2020-01-09 00:00:00-05:00      492955008
# 2020-01-09 00:00:00-05:00      494528000
# 2020-01-12 00:00:00-05:00      491926016
# 2020-01-13 00:00:00-05:00      495796992
#                                 ...
# 2022-10-08 00:00:00-04:00    10187599872
# 2022-10-30 00:00:00-04:00    10201700352
# 2022-11-05 00:00:00-04:00    10201700352
# 2022-11-18 00:00:00-05:00    10445800448
# 2022-11-19 00:00:00-05:00    10201700352
# Length: 73, dtype: int64

# %%
AMAZON.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
AMAZON.hist = AMAZON.history(period="3Y")
AMAZON.hist
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-03-16 00:00:00-04:00  82.075500  87.972504  81.301498  84.457497
# 2020-03-17 00:00:00-04:00  88.773499  92.889000  84.461998  90.391998
# 2020-03-18 00:00:00-04:00  87.500000  92.083000  87.250000  91.500000
# 2020-03-19 00:00:00-04:00  93.000000  97.250000  91.632500  94.046501
# 2020-03-20 00:00:00-04:00  96.315498  97.849998  91.036499  92.304497
# ...                              ...        ...        ...        ...
# 2023-03-09 00:00:00-05:00  93.680000  96.209999  92.180000  92.250000
# 2023-03-10 00:00:00-05:00  92.669998  93.570000  90.250000  90.730003
# 2023-03-13 00:00:00-04:00  89.970001  94.019997  88.120003  92.430000
# 2023-03-14 00:00:00-04:00  93.830002  95.070000  92.709999  94.879997
# 2023-03-15 00:00:00-04:00  93.220001  96.669998  93.070396  96.199997
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
AMAZON.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'AMZN',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': Timestamp('1997-05-15 09:30:00-0400', tz='America/New_York'),
#  'regularMarketTime': Timestamp('2023-03-15 16:00:06-0400', tz='America/New_York'),
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 96.2,
#  'chartPreviousClose': 89.25,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'end': Timestamp('2023-03-15 09:30:00-0400', tz='America/New_York'),
#    'start': Timestamp('2023-03-15 04:00:00-0400', tz='America/New_York')},
#   'regular': {'end': Timestamp('2023-03-15 16:00:00-0400', tz='America/New_York'),
#    'start': Timestamp('2023-03-15 09:30:00-0400', tz='America/New_York')},
#   'post': {'end': Timestamp('2023-03-15 20:00:00-0400', tz='America/New_York'),
#    'start': Timestamp('2023-03-15 16:00:00-0400', tz='America/New_York')}},
#  'dataGranularity': '1d',
#  'range': '3y',
# ...
